# %% [markdown]
# # What is Pandas ?
# ## Pandas is a fast , powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the python programming language.

# %% [markdown]
# # Pandas Series?
# ## "Pandas Series is a one-dimensional labeled array capable of storing any data type and having an associated index."

# %% [markdown]
# ## Series = Single Column Data
# ## DataFrame = Multiple Series ka collection.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Create Series using python list.

# %%
country = ["India", "Pakistan", "Srilanka", "USA"]
pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2    Srilanka
# 3         USA
# dtype: object

# %%
country[2]
# Out:
# 'Srilanka'

# %%
batsman_run = [86,76,23,59,90]
pd.Series(batsman_run, dtype = 'int32')
# Out:
# 0    86
# 1    76
# 2    23
# 3    59
# 4    90
# dtype: int32

# %% [markdown]
# ## Custom Index

# %%
marks = [56,78,45,90]
subjects = ['Science','English','Hindi','Maths']
pd.Series(marks, index =subjects)
# Out:
# Science    56
# English    78
# Hindi      45
# Maths      90
# dtype: int64

# %%
## Setting a Name
ad_marks = pd.Series(marks, index =subjects,name = "Adarsh's Marks")

# %%
ad_marks
# Out:
# Science    56
# English    78
# Hindi      45
# Maths      90
# Name: Adarsh's Marks, dtype: int64

# %% [markdown]
# ## Create Series using dictionary

# %%
marks = {
    "Maths":90,
    "Hindi":78,
    "English": 87,
    "Science":67
}

marks_series = pd.Series(marks, name = "Adarsh's Marks")
marks_series
# Out:
# Maths      90
# Hindi      78
# English    87
# Science    67
# Name: Adarsh's Marks, dtype: int64

# %% [markdown]
# ## Series Attributes

# %%
marks_series.index ## it shows us the indexes
# Out:
# Index(['Maths', 'Hindi', 'English', 'Science'], dtype='object')

# %%
marks_series.is_unique ## It tells us that our values are unique or not
# Out:
# True

# %%
marks_series.values ## it shows us the values in the form of numpy array
# Out:
# array([90, 78, 87, 67])

# %%
marks_series.ndim
# Out:
# 1

# %%
marks_series.dtype
# Out:
# dtype('int64')

# %%
marks_series.name
# Out:
# "Adarsh's Marks"

# %%
marks_series.hasnans ## It tells us that we have nan value or not
# Out:
# False

# %%
marks_series.shape ## It tells us the shape
# Out:
# (4,)

# %%
marks_series.size ## It tells us total elements it stores
# Out:
# 4

# %% [markdown]
# ## Series using read_csv

# %%
df = pd.read_csv(r"C:\Users\adity\Downloads\subs.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
subs = df.squeeze("columns")

# %%
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %% [markdown]
# ## With 2 columns

# %%
df1 = pd.read_csv(r"C:\Users\adity\Downloads\kohli_ipl.csv", index_col= 'match_no')
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
runs = df1.squeeze()

# %%
runs
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
type(runs)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Series Methods

# %%
subs.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
subs.tail()
# Out:
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, dtype: int64

# %%
subs.sample(5) ## It shows a random in our series
# Out:
# 200    139
# 228    236
# 45     126
# 299    157
# 306    151
# Name: Subscribers gained, dtype: int64

# %%
subs.value_counts()
# Out:
# Subscribers gained
# 105    9
# 108    6
# 123    5
# 72     5
# 88     5
#       ..
# 125    1
# 139    1
# 124    1
# 57     1
# 144    1
# Name: count, Length: 180, dtype: int64

# %%
movies = pd.read_csv(r"C:\Users\adity\Downloads\bollywood.csv", index_col = "movie")
movies.squeeze()
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies.value_counts() ## It gives us the frequency count
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Kashmira Shah        1
# Kartik Elangovan     1
# Karisma Kapoor       1
# Karan Sharma         1
# Zulfi Sayed          1
# Name: count, Length: 566, dtype: int64

# %%
runs.sort_values(ascending = False).head(1).values ## To sort our values
# Out:
# array([113])

# %%
movie =movies.squeeze()

# %%
movie.sort_index()
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ## Series Maths Methods

# %%
runs.count() # how many non null values are present
# Out:
# np.int64(215)

# %%
subs.sum() ## It gives us the sum.
# Out:
# np.int64(49510)

# %%
runs.mean()
# Out:
# np.float64(30.855813953488372)

# %%
runs.median()
# Out:
# 24.0

# %%
runs.mode()
# Out:
# 0    0
# Name: runs, dtype: int64

# %%
runs.std()
# Out:
# 26.22980132830278

# %%
runs.var()
# Out:
# 688.0024777222344

# %%
runs.max()
# Out:
# 113

# %%
runs.min()
# Out:
# 0

# %%
runs.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %% [markdown]
# ## Series Indexing

# %%
## Integer Indexing     ## Series only works on positive indexing

# %%
x = pd.Series([12,13,24,46,56,78,23,4])
x[2]
# Out:
# np.int64(24)

# %%
movie[4]
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_6792\1365575220.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   movie[4]
# 'Mona Ambegaonkar'

# %% [markdown]
# ## Slicing

# %%
runs[5:16]
# Out:
# match_no
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# 16     2
# Name: runs, dtype: int64

# %%
runs[-5:]
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
movie[-5:]
# Out:
# movie
# Hum Tumhare Hain Sanam      Shah Rukh Khan
# Aankhen (2002 film)       Amitabh Bachchan
# Saathiya (film)               Vivek Oberoi
# Company (film)                  Ajay Devgn
# Awara Paagal Deewana          Akshay Kumar
# Name: lead, dtype: object

# %% [markdown]
# ## Fancy Indexing

# %%
runs[[1,3,4,5]]
# Out:
# match_no
# 1     1
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %% [markdown]
# ## Editing Series

# %%
## using indexing
marks_series[1] = 90
marks_series
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_6792\2917975844.py:2: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[1] = 90
# Maths      90
# Hindi      90
# English    87
# Science    67
# Name: Adarsh's Marks, dtype: int64

# %%
# What if an index doesn't exist
marks_series['SST']= 87 ## it insert this item in last
marks_series
# Out:
# Maths      90
# Hindi      90
# English    87
# Science    67
# SST        87
# Name: Adarsh's Marks, dtype: int64

# %%
runs[2:4]= [76,89] ## with slicing

# %%
runs
# Out:
# match_no
# 1       1
# 2      23
# 3      76
# 4      89
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
marks_series[marks_series<68]=80 ## By boolean indexing

# %%
marks_series
# Out:
# Maths      90
# Hindi      90
# English    87
# Science    80
# SST        87
# Name: Adarsh's Marks, dtype: int64

# %%
import numpy as np
## if we want to replace nan value
s = pd.Series([10,np.nan,30])

s.fillna(0, inplace=True)

# %%
s
# Out:
# 0    10.0
# 1     0.0
# 2    30.0
# dtype: float64

# %%
s.replace([10,30],[20,40],inplace = True)

# %%
s
# Out:
# 0    20.0
# 1     0.0
# 2    40.0
# dtype: float64

# %% [markdown]
# ## Series with Python Functionality

# %%
## Most Important Python Functions on Series
## Function	Kaam
## len(s)	Total elements
## type(s)	Object type
## min(s)	Minimum value
## max(s)	Maximum value
## sum(s)	Total
## sorted(s)	Sorted list
## list(s)	Convert to list
## dict(s)	Convert to dictionary
## for loop	Iterate
## in	Check index existence

# %%
len(runs)
# Out:
# 215

# %%
type(subs)
# Out:
# pandas.core.series.Series

# %%
print(min(runs))
print(max(runs))
# Out:
# 0
# 113

# %%
sum(runs)
# Out:
# 6774

# %%
sorted(s)
# Out:
# [0.0, 20.0, 40.0]

# %%
s = pd.Series(
    [86,76,23],
    index=['Virat','Rohit','Gill']
)

dict(s)
# Out:
# {'Virat': np.int64(86), 'Rohit': np.int64(76), 'Gill': np.int64(23)}

# %%
"Virat" in s
# Out:
# True

# %% [markdown]
# ## Boolean indexing on series

# %%
runs[runs >= 100].size
# Out:
# 5

# %%
runs[runs==0].size
# Out:
# 9

# %%
subs[subs>=200].size
# Out:
# 59

# %%
## Find actors who have done more than 20 movies
num_movies = movie.value_counts()
num_movies
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Diganth              1
# Parveen Kaur         1
# Seema Azmi           1
# Akanksha Puri        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %%
num_movies[num_movies>20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# ## Plotting graphs on series

# %%
subs.plot()
# Out:
# <Axes: >

# %%
movie.value_counts().head(20).plot(kind = 'bar')
# Out:
# <Axes: xlabel='lead'>
