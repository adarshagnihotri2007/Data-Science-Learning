# %%
import numpy as np
import pandas as pd

# %%
## Whenever we have data in tabular form so we can say that this is a dataframe in Pandas.
## Every row and a column in a dataframe is a series.

# %% [markdown]
# ## Creating Dataframe

# %%
## using list
student_data = [
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,50,2]
]

pd.DataFrame(student_data,columns = ['iq','Marks','Package'])
# Out:
#     iq  Marks  Package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
## using Dictionary
student_dict = {
    'name' : ['Ankit','Nitish','Adarsh','Varsha','Amit','Sourabh'],
    'iq' :[100,90,120,80,0,0],
    'Marks' :[80,70,100,50,0,0],
    'Package' : [10,7,14,2,0,0]
}
students =pd.DataFrame(student_dict)
students.set_index("name",inplace = True)
students
# Out:
#           iq  Marks  Package
# name
# Ankit    100     80       10
# Nitish    90     70        7
# Adarsh   120    100       14
# Varsha    80     50        2
# Amit       0      0        0
# Sourabh    0      0        0

# %%
## using read_csv

# %%
df = pd.read_csv(r"C:\Users\adity\Downloads\movies.csv")
df
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl = pd.read_csv(r"C:\Users\adity\Downloads\ipl-matches.csv")
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# ## DataFrame Attributes and methods

# %%
df.shape
# Out:
# (1629, 18)

# %%
df.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
students.values
# Out:
# array([[100,  80,  10],
#        [ 90,  70,   7],
#        [120, 100,  14],
#        [ 80,  50,   2],
#        [  0,   0,   0],
#        [  0,   0,   0]])

# %%
ipl.head()
df.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
ipl.tail()
# Out:
#          ID        City        Date   Season MatchNumber  \
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# ...

# %%
ipl.sample(5)
# Out:
#           ID       City        Date Season MatchNumber                  Team1  \
# 641   548368    Kolkata  2012-05-14   2012          63  Kolkata Knight Riders
# 288  1136586      Delhi  2018-04-27   2018          26       Delhi Daredevils
# 90   1254091    Sharjah  2021-09-30   2021          44    Sunrisers Hyderabad
# 837   392237  Centurion  2009-05-22   2009  Semi Final       Delhi Daredevils
# 611   598013    Kolkata  2013-04-14   2013          17  Kolkata Knight Riders
#
#                      Team2                    Venue             TossWinner  \
# 641    Chennai Super Kings             Eden Gardens    Chennai Super Kings
# 288  Kolkata Knight Riders     Arun Jaitley Stadium  Kolkata Knight Riders
# 90     Chennai Super Kings  Sharjah Cricket Stadium    Chennai Super Kings
# 837        Deccan Chargers          SuperSport Park        Deccan Chargers
# 611    Sunrisers Hyderabad             Eden Gardens  Kolkata Knight Riders
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
df.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
ipl.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
students.duplicated().sum()
# Out:
# np.int64(1)

# %%
#rename
## It is used to rename our columns name

# %%
students.rename(columns ={'marks':'percent','package':"LPA"})
# Out:
#           iq  Marks  Package
# name
# Ankit    100     80       10
# Nitish    90     70        7
# Adarsh   120    100       14
# Varsha    80     50        2
# Amit       0      0        0
# Sourabh    0      0        0

# %%
students.rename(columns ={'marks':'percent','package':'LPA'})
# Out:
#           iq  Marks  Package
# name
# Ankit    100     80       10
# Nitish    90     70        7
# Adarsh   120    100       14
# Varsha    80     50        2
# Amit       0      0        0
# Sourabh    0      0        0

# %%
students
# Out:
#           iq  Marks  Package
# name
# Ankit    100     80       10
# Nitish    90     70        7
# Adarsh   120    100       14
# Varsha    80     50        2
# Amit       0      0        0
# Sourabh    0      0        0

# %%
students.rename(columns = {"Marks":"Percentage","Package":"LPA"},inplace = True)

# %%
students
# Out:
#           iq  Percentage  LPA
# name
# Ankit    100          80   10
# Nitish    90          70    7
# Adarsh   120         100   14
# Varsha    80          50    2
# Amit       0           0    0
# Sourabh    0           0    0

# %% [markdown]
# ## Mathematical methods

# %%
df.sum(numeric_only=True, axis = 1)
# Out:
# 0       37139.4
# 1        2096.1
# 2        7574.1
# 3        3916.0
# 4        2305.3
#          ...
# 1624     2283.9
# 1625     2137.0
# 1626     2037.1
# 1627     2064.4
# 1628     4988.0
# Length: 1629, dtype: float64

# %%
students.sum(numeric_only=True, axis = 1)
# Out:
# name
# Ankit      190
# Nitish     167
# Adarsh     234
# Varsha     132
# Amit         0
# Sourabh      0
# dtype: int64

# %%
students.mean()
# Out:
# iq            65.0
# Percentage    50.0
# LPA            5.5
# dtype: float64

# %%
students.max()
# Out:
# iq            120
# Percentage    100
# LPA            14
# dtype: int64

# %%
students.median()
# Out:
# iq            85.0
# Percentage    60.0
# LPA            4.5
# dtype: float64

# %%
students.std()
# Out:
# iq            52.057660
# Percentage    41.952354
# LPA            5.787918
# dtype: float64

# %% [markdown]
# ## Select column from an dataframe

# %%
## Fetching single column
df['title_x']
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %%
## Fetching more than one column
df[['title_x','imdb_id']]
# Out:
#                                    title_x     imdb_id
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
# [1629 rows x 2 columns]

# %% [markdown]
# ## Selecting rows from an DataFrame
# ### iloc - searches using index positions
# ### loc - searches using index labels

# %%
df.iloc[[0,3]]
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 3           Why Cheat India  tt8108208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 3           Why Cheat India           Why Cheat India         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 3             2019     121       Crime|Drama          6.0        1891
#
#                                                story  \
# ...

# %%
students.loc["Adarsh":"Sourabh"]
# Out:
#           iq  Percentage  LPA
# name
# Adarsh   120         100   14
# Varsha    80          50    2
# Amit       0           0    0
# Sourabh    0           0    0

# %%
students.iloc[0,1]
# Out:
# np.int64(80)

# %%
students
# Out:
#           iq  Percentage  LPA
# name
# Ankit    100          80   10
# Nitish    90          70    7
# Adarsh   120         100   14
# Varsha    80          50    2
# Amit       0           0    0
# Sourabh    0           0    0

# %%
df.iloc[0:3,0:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %% [markdown]
# # Filtering a Dataframe

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
## Find all the final winners?
mask =ipl['MatchNumber']=='Final'
new_df =ipl[mask]
new_df[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
ipl[ipl['MatchNumber']=="Final"][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
## que2. How many super over finishes have occured
ipl[ipl['SuperOver']=='Y']['SuperOver'].count()
# Out:
# np.int64(14)

# %%
ipl[ipl['SuperOver'] == 'Y'].shape[0]
# Out:
# 14

# %%
(ipl['SuperOver']=='Y').sum()
# Out:
# np.int64(14)

# %%
ipl.head(1)
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision SuperOver     WinningTeam    WonBy  Margin method  \
# 0          bat         N  Gujarat Titans  Wickets     7.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon

# %%
## que3. How many matches CSK won in Kolkata
ipl[(ipl['WinningTeam']=='Chennai Super Kings') & (ipl['City']=='Kolkata')].shape[0]
# Out:
# 5

# %%
## que4. Toss winner is match winner in percentage.
(ipl['TossWinner']==ipl['WinningTeam']).mean()*100
# Out:
# np.float64(51.473684210526315)

# %%
ipl[ipl['TossWinner']==ipl['WinningTeam']].shape[0]/ipl.shape[0]*100
# Out:
# 51.473684210526315

# %%
## Movies with rating higher than 8 and votes>10000
df[(df['imdb_rating']>8)&(df['imdb_votes']>1000)][['imdb_rating','imdb_votes']]
# Out:
#       imdb_rating  imdb_votes
# 0             8.4       35112
# 11            8.2       22440
# 37            8.3       13417
# 40            8.2       13972
# 53            8.4        1841
# 58            8.7        1379
# 59            8.2        1369
# 62            8.9        1902
# 64            8.1        1440
# 84            8.1        5434
# 143           8.2       16535
# 146           8.4       51615
# 192           8.6        7239
# 279           8.4        4530
# 325           8.2       33902
# 354           8.4      131338
# 418           8.1       19904
# 426           8.2       58340
# 436           8.2       26612
# 469           8.2       56406
# 536           8.1       46912
# 566           8.1       17483
# 567           8.1      143605
# 589           8.2       38016
# 612           8.2       56205
# 638           8.3       13537
# 668           8.2       29994
# 669           8.1       53181
# 693           8.2       71636
# 694           8.2       71636
# ...

# %%
## Action movies with rating higher than 7.5
mask1 =df['genres'].str.split('|').apply(lambda x:'Action' in x)
mask2 = df['imdb_rating']>7.5
df[(mask1) & (mask2)].shape[0]
# Out:
# 33

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
def head_to_head(team1,team2):

    temp = ipl[((ipl['Team1']==team1) & (ipl['Team2']==team2)) |
        ((ipl['Team1']==team2) & (ipl['Team2']==team1))
        ]
    print("Total Matches:", temp.shape[0])
    print(team1, 'Won:',(temp['WinningTeam']==team1).sum())
    print(team2, "Won:", (temp['WinningTeam']==team2).sum())

# %%
## now we will call our function
head_to_head('Royal Challengers Bangalore','Chennai Super Kings')
# Out:
# Total Matches: 29
# Royal Challengers Bangalore Won: 10
# Chennai Super Kings Won: 19

# %% [markdown]
# ## Adding new columns-- completely new

# %%
df['Country'] = 'India'
df.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %% [markdown]
# ## Adding new column -- From existing ones

# %%
df.dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 298 entries, 11 to 1623
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           298 non-null    object
#  1   imdb_id           298 non-null    object
#  2   poster_path       298 non-null    object
#  3   wiki_link         298 non-null    object
#  4   title_y           298 non-null    object
#  5   original_title    298 non-null    object
#  6   is_adult          298 non-null    int64
#  7   year_of_release   298 non-null    int64
#  8   runtime           298 non-null    object
#  9   genres            298 non-null    object
#  10  imdb_rating       298 non-null    float64
#  11  imdb_votes        298 non-null    int64
#  12  story             298 non-null    object
#  13  summary           298 non-null    object
#  14  tagline           298 non-null    object
#  15  actors            298 non-null    object
# ...

# %%
df['Lead_Actor']=df['actors'].str.split('|').apply(lambda x:x[0])
df
# Out:
#                       title_x     imdb_id  \
# 11                  Gully Boy   tt2395469
# 34              Yeh Hai India   tt5525846
# 37          Article 15 (film)  tt10324144
# 87                    Aiyaary   tt6774212
# 96           Raid (2018 film)   tt7363076
# ...                       ...         ...
# 1600                   Kasoor   tt0272688
# 1601         Maya (2001 film)   tt0299027
# 1607  Nayak (2001 Hindi film)   tt0291376
# 1621                  Tum Bin   tt0290326
# 1623                 Zubeidaa   tt0255713
#
#                                             poster_path  \
# 11    https://upload.wikimedia.org/wikipedia/en/thum...
# 34    https://upload.wikimedia.org/wikipedia/en/thum...
# 37    https://upload.wikimedia.org/wikipedia/en/thum...
# 87    https://upload.wikimedia.org/wikipedia/en/thum...
# 96    https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1600  https://upload.wikimedia.org/wikipedia/en/thum...
# ...
